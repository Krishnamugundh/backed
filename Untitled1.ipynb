# %%
import pandas as pd

# %%
df1 = pd.read_hdf("artifacts/redeemed_data/final_data_001.h5","original_data")

# %%
df1.tail(4)
# Out:
#            ID  Age Gender     Occupation status  VHI Score  RSI Score Smoker  \
# 204  voice205   30      f           Hairstylist         62         19    yes
# 205  voice206   22      f                Singer          0          6     no
# 206  voice207   30      f                Singer          0         26     no
# 207  voice208   39      f  Call center operator         32         15     no
#
#     Cigarettes per day Alcohol consumption Glasses of alcohol per day  ...  \
# 204                 15      casual drinker                         NU  ...
# 205                 NU          nondrinker                         NU  ...
# 206                 NU          nondrinker                         NU  ...
# 207                 NU          nondrinker                         NU  ...
#
#         Coffee Cups of coffee per day      Chocolate  \
# 204     always                    3.0  almost always
# 205  sometimes                    NaN      sometimes
# ...

# %%
sample_1 = df1.iloc[1:2,:].to_dict('list')

df2 = pd.DataFrame(sample_1)

# The first row was sucessfully added as last row.

df1 = df1._append(df2,ignore_index=True)

# %%
df1.tail(3)
# Out:
#            ID  Age Gender Occupation status  VHI Score  RSI Score  Smoker  \
# 208  voice002   55      m          Employee         17         12  casual
# 209  voice002   55      m          Employee         17         12  casual
# 210  voice002   55      m          Employee         17         12  casual
#
#     Cigarettes per day Alcohol consumption Glasses of alcohol per day  ...  \
# 208                  2    habitual drinker                          1  ...
# 209                  2    habitual drinker                          1  ...
# 210                  2    habitual drinker                          1  ...
#
#         Coffee Cups of coffee per day  Chocolate Gramme of chocolate per day  \
# 208  sometimes                    3.0  sometimes                        None
# 209  sometimes                    3.0  sometimes                        None
# 210  sometimes                    3.0  sometimes                        None
#
# ...

# %%
df1.to_hdf("artifacts/redeemed_data/final_data_001.h5",key="original_data",)
